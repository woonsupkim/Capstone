# %% [markdown]
# # Sentiment Analysis and Zero-Shot Classification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('Corrys.csv', index_col = [0])

# %%
df
# Out:
#       segment  review_id                        product_name  \
# 13883  Garden      79100  Corry’s Slug & Snail Killer 1.75lb
# 14224  Garden      80027   Corry’s Slug & Snail Killer 3.5lb
# 17059  Garden     110633     Corry’s Slug & Snail Killer 8lb
# 15653  Garden     100248     Corry’s Slug & Snail Killer 8lb
# 28434  Garden     150347   Corry’s Slug & Snail Killer 3.5lb
# ...       ...        ...                                 ...
# 25576  Garden     141508     Corry’s Slug & Snail Killer 8lb
# 25525  Garden     141457  Corry’s Slug & Snail Killer 1.75lb
# 25591  Garden     141523     Corry’s Slug & Snail Killer 8lb
# 25562  Garden     141494   Corry’s Slug & Snail Killer 3.5lb
# 11469  Garden      73132         8 lb. Slug and Snail Killer
#
#                                               producturl   retailer   brand  \
# 13883               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 14224               https://www.amazon.com/dp/B00CYNH3RE     Amazon  Corrys
# 17059               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 15653               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 28434  https://www.walmart.com//ip/Corry-s-Ready-to-U...    Walmart  Corrys
# ...                                                  ...        ...     ...
# 25576               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 25525               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 25591               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 25562               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 11469               http://www.homedepot.com/p/203636436  Homedepot  Corrys
#
#       retailer_product_id     base_id variants_flag review_creation_date  \
# 13883           203636436   203636436           Yes  2022-04-01T00:00:00
# 14224          B00CYNH3RE  B00CYNH3RE            No  2022-04-08T00:00:00
# 17059           203636415   203636436           Yes  2022-05-04T00:00:00
# 15653           203636415   203636436           Yes  2022-04-19T00:00:00
# 28434            38441939    38441939            No  2022-06-04T00:00:00
# ...                   ...         ...           ...                  ...
# 25576           203636415   203636436           Yes  2022-06-08T00:00:00
# 25525           203636436   203636436           Yes  2022-06-01T00:00:00
# 25591           203636415   203636436           Yes  2022-06-01T00:00:00
# 25562           203636434   203636436           Yes  2022-06-15T00:00:00
# 11469           203636415   203636436           Yes  2022-02-15T00:00:00
#
#        year  month  week                                       review_title  \
# 13883  2022      4    13           Trying to used for gopher not working...
# 14224  2022      4    14                              Knowing that it works
# 17059  2022      5    18  Works on city snails but the country ones just...
# 15653  2022      4    16   I use Corrys slug and snail killer as my back...
# 28434  2022      6    22                                  Works quite well!
# ...     ...    ...   ...                                                ...
# 25576  2022      6    23                 No more slugs eating my plants....
# 25525  2022      6    22    Works well to keep slug out of my garden. No...
# 25591  2022      6    22  this is a great product, however it will draw ...
# 25562  2022      6    24                             Misleading information
# 11469  2022      2     7  Corrys does a decent job of removing slugs and...
#
#                                              review_text      review_type  \
# 13883              Trying to used for gopher not working  organic reviews
# 14224                                 Works like a dream  organic reviews
# 17059  Works on city snails but the country ones just...  organic reviews
# 15653  I use Corrys slug and snail killer as my back ...  organic reviews
# 28434  I had used the Eliminator product many seasons...  organic reviews
# ...                                                  ...              ...
# 25576                    No more slugs eating my plants.  organic reviews
# 25525  Works well to keep slug out of my garden. No i...  organic reviews
# 25591  this is a great product, however it will draw ...  organic reviews
# 25562  1) This product does not provide the coverage ...  organic reviews
# 11469  Corrys does a decent job of removing slugs and...  organic reviews
#
#        price  rating  images  videos  helpful_votes promotion_flag  \
# 13883   7.97       1       0       0              0             No
# 14224  12.88       5       0       0              0             No
# 17059  23.97       5       0       0              0             No
# 15653  23.97       4       0       0              0             No
# 28434  12.46       5       0       0              0             No
# ...      ...     ...     ...     ...            ...            ...
# 25576  23.97       5       0       0              0             No
# 25525   7.97       3       0       0              0             No
# 25591  23.97       4       0       0              0             No
# 25562  13.97       3       0       0              0             No
# 11469  23.97       4       0       0              0             No
#
#                                             review_lower        date  \
# 13883              trying to used for gopher not working  2022-04-01
# 14224                                 works like a dream  2022-04-08
# 17059  works on city snails but the country ones just...  2022-05-04
# 15653  i use corrys slug and snail killer as my back ...  2022-04-19
# 28434  i had used the eliminator product many seasons...  2022-06-04
# ...                                                  ...         ...
# 25576                    no more slugs eating my plants.  2022-06-08
# 25525  works well to keep slug out of my garden. no i...  2022-06-01
# 25591  this is a great product, however it will draw ...  2022-06-01
# 25562  1) this product does not provide the coverage ...  2022-06-15
# 11469  corrys does a decent job of removing slugs and...  2022-02-15
#
#        word_count
# 13883           7
# 14224           4
# 17059          10
# 15653          52
# 28434          95
# ...           ...
# 25576           6
# 25525          30
# 25591          10
# 25562          21
# 11469          10
#
# [400 rows x 25 columns]

# %% [markdown]
# # Sentiment Analysis

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 5.1 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 36.7 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 59.6 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.2 transformers-4.24.0

# %%
from transformers import pipeline

# %%
sentiment_pipeline = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# Downloading:   0%|          | 0.00/929 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
#sample sentiment analysis
sample_review = list(df['review_text'])[1]
result = sentiment_pipeline(sample_review)
result
# Out:
# [{'label': 'Positive', 'score': 0.7835007309913635}]

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

sentiment = []
index = -1
for sentence in df['review_lower']:
    index+=1
    if(index%20 == 0):
        print(index)

    result = sentiment_pipeline(sentence[:512])[0]
    sentiment.append(result['label'])
df['sentiment'] = sentiment
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380

# %%
df
# Out:
#       segment  review_id                        product_name  \
# 13883  Garden      79100  Corry’s Slug & Snail Killer 1.75lb
# 14224  Garden      80027   Corry’s Slug & Snail Killer 3.5lb
# 17059  Garden     110633     Corry’s Slug & Snail Killer 8lb
# 15653  Garden     100248     Corry’s Slug & Snail Killer 8lb
# 28434  Garden     150347   Corry’s Slug & Snail Killer 3.5lb
# ...       ...        ...                                 ...
# 25576  Garden     141508     Corry’s Slug & Snail Killer 8lb
# 25525  Garden     141457  Corry’s Slug & Snail Killer 1.75lb
# 25591  Garden     141523     Corry’s Slug & Snail Killer 8lb
# 25562  Garden     141494   Corry’s Slug & Snail Killer 3.5lb
# 11469  Garden      73132         8 lb. Slug and Snail Killer
#
#                                               producturl   retailer   brand  \
# 13883               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 14224               https://www.amazon.com/dp/B00CYNH3RE     Amazon  Corrys
# 17059               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 15653               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 28434  https://www.walmart.com//ip/Corry-s-Ready-to-U...    Walmart  Corrys
# ...                                                  ...        ...     ...
# 25576               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 25525               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 25591               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 25562               http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 11469               http://www.homedepot.com/p/203636436  Homedepot  Corrys
#
#       retailer_product_id     base_id variants_flag review_creation_date  \
# 13883           203636436   203636436           Yes  2022-04-01T00:00:00
# 14224          B00CYNH3RE  B00CYNH3RE            No  2022-04-08T00:00:00
# 17059           203636415   203636436           Yes  2022-05-04T00:00:00
# 15653           203636415   203636436           Yes  2022-04-19T00:00:00
# 28434            38441939    38441939            No  2022-06-04T00:00:00
# ...                   ...         ...           ...                  ...
# 25576           203636415   203636436           Yes  2022-06-08T00:00:00
# 25525           203636436   203636436           Yes  2022-06-01T00:00:00
# 25591           203636415   203636436           Yes  2022-06-01T00:00:00
# 25562           203636434   203636436           Yes  2022-06-15T00:00:00
# 11469           203636415   203636436           Yes  2022-02-15T00:00:00
#
#        year  month  week                                       review_title  \
# 13883  2022      4    13           Trying to used for gopher not working...
# 14224  2022      4    14                              Knowing that it works
# 17059  2022      5    18  Works on city snails but the country ones just...
# 15653  2022      4    16   I use Corrys slug and snail killer as my back...
# 28434  2022      6    22                                  Works quite well!
# ...     ...    ...   ...                                                ...
# 25576  2022      6    23                 No more slugs eating my plants....
# 25525  2022      6    22    Works well to keep slug out of my garden. No...
# 25591  2022      6    22  this is a great product, however it will draw ...
# 25562  2022      6    24                             Misleading information
# 11469  2022      2     7  Corrys does a decent job of removing slugs and...
#
#                                              review_text      review_type  \
# 13883              Trying to used for gopher not working  organic reviews
# 14224                                 Works like a dream  organic reviews
# 17059  Works on city snails but the country ones just...  organic reviews
# 15653  I use Corrys slug and snail killer as my back ...  organic reviews
# 28434  I had used the Eliminator product many seasons...  organic reviews
# ...                                                  ...              ...
# 25576                    No more slugs eating my plants.  organic reviews
# 25525  Works well to keep slug out of my garden. No i...  organic reviews
# 25591  this is a great product, however it will draw ...  organic reviews
# 25562  1) This product does not provide the coverage ...  organic reviews
# 11469  Corrys does a decent job of removing slugs and...  organic reviews
#
#        price  rating  images  videos  helpful_votes promotion_flag  \
# 13883   7.97       1       0       0              0             No
# 14224  12.88       5       0       0              0             No
# 17059  23.97       5       0       0              0             No
# 15653  23.97       4       0       0              0             No
# 28434  12.46       5       0       0              0             No
# ...      ...     ...     ...     ...            ...            ...
# 25576  23.97       5       0       0              0             No
# 25525   7.97       3       0       0              0             No
# 25591  23.97       4       0       0              0             No
# 25562  13.97       3       0       0              0             No
# 11469  23.97       4       0       0              0             No
#
#                                             review_lower        date  \
# 13883              trying to used for gopher not working  2022-04-01
# 14224                                 works like a dream  2022-04-08
# 17059  works on city snails but the country ones just...  2022-05-04
# 15653  i use corrys slug and snail killer as my back ...  2022-04-19
# 28434  i had used the eliminator product many seasons...  2022-06-04
# ...                                                  ...         ...
# 25576                    no more slugs eating my plants.  2022-06-08
# 25525  works well to keep slug out of my garden. no i...  2022-06-01
# 25591  this is a great product, however it will draw ...  2022-06-01
# 25562  1) this product does not provide the coverage ...  2022-06-15
# 11469  corrys does a decent job of removing slugs and...  2022-02-15
#
#        word_count sentiment
# 13883           7   Neutral
# 14224           4   Neutral
# 17059          10   Neutral
# 15653          52   Neutral
# 28434          95  Positive
# ...           ...       ...
# 25576           6  Negative
# 25525          30  Positive
# 25591          10  Positive
# 25562          21  Negative
# 11469          10   Neutral
#
# [400 rows x 26 columns]

# %% [markdown]
# ## Zero Shot Classificaiton

# %%
import transformers
from transformers import pipeline

# %%
classifier  = pipeline("zero-shot-classification",  model = "facebook/bart-large-mnli")
# Out:
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# ## Sample Classification

# %% [markdown]
# this is where you can play around with the labels to see which ones would make sense

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[1]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': 'Works like a dream',
#  'labels': ['quality', 'satisfaction', 'affordability', 'complaints'],
#  'scores': [0.9971891045570374,
#   0.9076296091079712,
#   0.7898093461990356,
#   0.00010972993186442181]}

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[2]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': 'Works on city snails but the country ones just laugh.',
#  'labels': ['quality', 'complaints', 'affordability', 'satisfaction'],
#  'scores': [0.5196501612663269,
#   0.31912538409233093,
#   0.12050621211528778,
#   0.09660077840089798]}

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[3]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': 'I use Corrys slug and snail killer as my back up as I usually hand collect as many snails as I can and dispose of in trash.  Corrys is easy to apply and I try to keep it underneath plants so my pets arent eating it.  Corrys does the job.',
#  'labels': ['quality', 'affordability', 'satisfaction', 'complaints'],
#  'scores': [0.9853120446205139,
#   0.8280582427978516,
#   0.7640513181686401,
#   0.16799254715442657]}

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[4]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': 'I had used the Eliminator product many seasons in the past- and it worked well. This previous Spring, it wasnt readily available, as my cabbages were taking damage from those slimy pests. So, I looked into Corrys. I bought 2 of the small boxes and spread them around the perimeter of my veggie garden. Three days later, snail shells and dying snails everywhere. Yes, this works quite well. I then purchased 3 more boxes (this time the large ones) so I would be ready for the next year or two. Highly recommended- easy to apply.',
#  'labels': ['quality', 'satisfaction', 'affordability', 'complaints'],
#  'scores': [0.9857211112976074,
#   0.834513247013092,
#   0.6696500778198242,
#   0.07789874076843262]}

# %% [markdown]
# # Zero Shot Classification (Entire data)

# %% [markdown]
# Using the labels you identified above, you want to now run it through the entire data

# %%
classifier  = pipeline("zero-shot-classification",  model = "facebook/bart-large-mnli")

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.24.0-py3-none-any.whl (5.5 MB)
#      |████████████████████████████████| 5.5 MB 32.3 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 68.6 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 113.9 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.10.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.2 transformers-4.24.0

# %%
# insert the labels you identified from above section
type = ['cost', 'efficient', 'effective', 'ease of use']

# %%
#setting empty values for the columns
index = -1
for label in type:
    df[label + '_m'] = -1

for j in range(len(df)):
    #counter for progress/debugging
    index+=1
    if(index%20 == 0): 
        print(index)
        
    #running the classifier on the column    
    res = classifier(
        df.iloc[j]['review_lower'],
        candidate_labels = type,
        multi_label = True
    )
    #setting the column values according to the output from the classifier ("_m" = multiclass)
    for i in range(len(res['labels'])):
        df[res['labels'][i]+ '_m'].iloc[j] = res['scores'][i]
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380

# %%
# create a "max" column for metric purposes
df['max'] = df[['cost_m', 'efficient_m', 'effective_m', 'ease of use_m']].max(axis=1)

# %%
#assign the max to its aligned type
align_list=[]
for i in range(len(df)):
  for t in type:
    if df[t+'_m'].iloc[i] == df['max'].iloc[i]:
      align_list.append(t)
      
df['align_type']=align_list

# %%
df.head(3)
# Out:
#       segment  review_id                        product_name  \
# 13883  Garden      79100  Corry’s Slug & Snail Killer 1.75lb
# 14224  Garden      80027   Corry’s Slug & Snail Killer 3.5lb
# 17059  Garden     110633     Corry’s Slug & Snail Killer 8lb
#
#                                  producturl   retailer   brand  \
# 13883  http://www.homedepot.com/p/203636436  Homedepot  Corrys
# 14224  https://www.amazon.com/dp/B00CYNH3RE     Amazon  Corrys
# 17059  http://www.homedepot.com/p/203636436  Homedepot  Corrys
#
#       retailer_product_id     base_id variants_flag review_creation_date  \
# 13883           203636436   203636436           Yes  2022-04-01T00:00:00
# 14224          B00CYNH3RE  B00CYNH3RE            No  2022-04-08T00:00:00
# 17059           203636415   203636436           Yes  2022-05-04T00:00:00
#
#        year  month  week                                       review_title  \
# 13883  2022      4    13           Trying to used for gopher not working...
# 14224  2022      4    14                              Knowing that it works
# 17059  2022      5    18  Works on city snails but the country ones just...
#
#                                              review_text      review_type  \
# 13883              Trying to used for gopher not working  organic reviews
# 14224                                 Works like a dream  organic reviews
# 17059  Works on city snails but the country ones just...  organic reviews
#
#        price  rating  images  videos  helpful_votes promotion_flag  \
# 13883   7.97       1       0       0              0             No
# 14224  12.88       5       0       0              0             No
# 17059  23.97       5       0       0              0             No
#
#                                             review_lower        date  \
# 13883              trying to used for gopher not working  2022-04-01
# 14224                                 works like a dream  2022-04-08
# 17059  works on city snails but the country ones just...  2022-05-04
#
#        word_count sentiment    cost_m  efficient_m  effective_m  \
# 13883           7   Neutral  0.183160     0.001425     0.002358
# 14224           4   Neutral  0.060324     0.996168     0.998745
# 17059          10   Neutral  0.572902     0.268338     0.964917
#
#        ease of use_m  affordability_m  quality_m  satisfaction_m       max  \
# 13883       0.001929         0.001321   0.043219        0.000799  0.183160
# 14224       0.996628         0.789618   0.997467        0.929842  0.998745
# 17059       0.024634         0.131567   0.433096        0.096121  0.964917
#
#       align_type
# 13883       cost
# 14224  effective
# 17059  effective

# %% [markdown]
# # Heatmap

# %%
import seaborn as sns

# %%
# Create Pivot table for the Heatmap
table_count = pd.pivot_table(df, values='max', index=['sentiment'], columns=['align_type'], aggfunc='count', margins=True, 
                       dropna=True, fill_value=0)
table_count
# Out:
# align_type  cost  ease of use  effective  efficient  All
# sentiment
# Negative      53            0         72          3  128
# Neutral       18            6         79          5  108
# Positive       1            7        152          4  164
# All           72           13        303         12  400

# %%
#count the percentage
table2 = table_count.div( table_count.iloc[-1,:], axis=1 ).applymap('{:.0%}'.format)
table2=table2.drop('All').drop(labels='All', axis=1)
table2
# Out:
# align_type cost ease of use effective efficient
# sentiment
# Negative    74%          0%       24%       25%
# Neutral     25%         46%       26%       42%
# Positive     1%         54%       50%       33%

# %%
#Drop "ALL" column and row
table_count=table_count.drop('All').drop(labels='All', axis=1)

# %%
#reshape results
results=np.asarray(table2)

# %%
#check results
results
# Out:
# array([['74%', '0%', '24%', '25%'],
#        ['25%', '46%', '26%', '42%'],
#        ['1%', '54%', '50%', '33%']], dtype=object)

# %%
# Heatmap

plt.figure(figsize=(12, 5))
sns.set(font_scale=1.4)
# Reds
data1 = table_count.copy()
data1.loc['Negative'] = float('nan')
data1.loc['Neutral'] = float('nan')
ax=sns.heatmap(data1, annot=results, cmap="Greens",alpha=0.75,fmt="",annot_kws={"fontsize":15},linewidth=0.1,cbar=False)
ax.set(xlabel="", ylabel="")

# Blue
data2 = table_count.copy()
data2.loc['Negative'] = float('nan')
data2.loc['Positive'] = float('nan')
ax=sns.heatmap(data2, annot=results, cmap="Blues", alpha=0.75,fmt="",annot_kws={"fontsize":15},linewidth=0.1,cbar=False)
ax.set(xlabel="", ylabel="")
# Greens
data3 = table_count.copy()
data3.loc['Positive'] = float('nan')
data3.loc['Neutral'] = float('nan')
ax=sns.heatmap(data3, annot=results, cmap="Reds", alpha=0.75,fmt="",annot_kws={"fontsize":15},linewidth=0.1,cbar=False)
ax.set(xlabel="", ylabel="")
# Out:
# [Text(79.5, 0.5, ''), Text(0.5, 16.5, '')]
# [Text(79.5, 0.5, ''), Text(0.5, 16.5, '')]
# [Text(79.5, 0.5, ''), Text(0.5, 16.5, '')]

# %% [markdown]
# # Metric and Sanity Check

# %%
sns.set_style('ticks');
fig, ax = plt.subplots();
ax = sns.histplot(x = 'max', data = df);
plt.axvline(0.7, 0,700, c = 'r', ls = '--');
#for container in ax.containers:
#    ax.bar_label(container);

len(df[df['max'] > 0.7])/len(df['max'])
#subcategories of quality. may be too broad


list(df[df['max'] > 0.7]['review_lower'][1:2])
# Out:
# 0.8575
# ['works on city snails but the country ones just laugh.']

# %%
# to see how many uncategorized data remains
df_uncat = df[df['cost_m'] < 0.7]
df_uncat = df_uncat[df_uncat['efficient_m'] < 0.7]
df_uncat = df_uncat[df_uncat['effective_m'] < 0.7]
df_uncat = df_uncat[df_uncat['ease of use_m'] < 0.7]
#df_uncat.info()

# %%
len(df_uncat)
# Out:
# 63

# %%
#df_uncat.to_csv('data/unlabeld_data.csv')
