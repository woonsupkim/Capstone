# %% [markdown]
# # Sentiment Analysis and Zero-Shot Classification

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('PenningtonGrass.csv', index_col = [0])

# %% [markdown]
# # Sentiment Analysis

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 5.2 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 53.4 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 34.2 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.9.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.23.1

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# Downloading:   0%|          | 0.00/929 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
#sample sentiment analysis
sample_review = list(df['review_text'])[1]
result = sentiment_pipeline(sample_review)
result
# Out:
# [{'label': 'Negative', 'score': 0.9278885722160339}]

# %%
from transformers import pipeline
sentiment_pipeline = pipeline("sentiment-analysis", model="cardiffnlp/twitter-roberta-base-sentiment-latest")

sentiment = []
index = -1
for sentence in df['review_lower']:
    index+=1
    if(index%20 == 0):
        print(index)

    result = sentiment_pipeline(sentence[:512])[0]
    sentiment.append(result['label'])
df['sentiment'] = sentiment
# Out:
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380

# %% [markdown]
# ## Zero Shot Classificaiton

# %%
import transformers
from transformers import pipeline

# %%
classifier  = pipeline("zero-shot-classification",  model = "facebook/bart-large-mnli")
# Out:
# Downloading:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# ## Sample Classification

# %% [markdown]
# this is where you can play around with the labels to see which ones would make sense

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[1]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': 'I followed the instructions and no grass has grown at all. Disappointed. Waste of money.',
#  'labels': ['complaints', 'affordability', 'quality', 'satisfaction'],
#  'scores': [0.7503145337104797,
#   0.040001265704631805,
#   0.007417358458042145,
#   0.0008372272714041173]}

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[2]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': '[This review was collected as part of a promotion.] Worked perfectly. Covered up the areas were I had patches of dried grass. I dont consider myself having a green thumb but even for me it was easy. Covers a wide area. Just use as directed. Pleased with my results.',
#  'labels': ['quality', 'satisfaction', 'affordability', 'complaints'],
#  'scores': [0.9952090978622437,
#   0.9602085947990417,
#   0.3736151456832886,
#   0.00278640678152442]}

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[3]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': '[This review was collected as part of a promotion.] It wasnt until I tried Pennington Smart Patch Sun & Shade Mix that I could finally repair the bare spots in my lawns caused by my dogs and lawn disease. This is so simple to use by raking and clearing debris, shaking on Smart patch, and then watering the area well. I can actually see new growth within one week and with the built-in mulch, it turns a lighter color so you know to water that area. This works well in either sun or shade and even has what they call a tackifier that acts as a blanket to cover and protect the seed from washing away so you know it will germinate and grow. This truly is the answer for me to have a complete lawn without any brown or bare spots. It just doesnt get any easier to have the lawn of envy. Thanks Pennington for making my life so much easier!',
#  'labels': ['quality', 'satisfaction', 'affordability', 'complaints'],
#  'scores': [0.9789014458656311,
#   0.8845852613449097,
#   0.6390148401260376,
#   0.13660243153572083]}

# %%
# play around with the "candidate_labels"
sample_review = list(df['review_text'])[4]

res = classifier(
    sample_review,
    candidate_labels = ['affordability', 'quality', 'satisfaction', 'complaints'], 
    multi_label = True
)
res
# Out:
# {'sequence': '[This review was collected as part of a promotion.] Have been struggling to grow grass under a large old shady tree for a long time. So was happy to try Pennington Smart Patch Dense Shade Mix. Was easy to use & gave it a good watering daily to get it going ! Was excited to see results within a week in a few areas, where nothing has been able to grow before! Looking forward to the whole area being covered completely soon. Very impressed with the results so far.',
#  'labels': ['quality', 'satisfaction', 'affordability', 'complaints'],
#  'scores': [0.9946915507316589,
#   0.9770030379295349,
#   0.40836310386657715,
#   0.05536486208438873]}

# %% [markdown]
# # Zero Shot Classification (Entire data)

# %% [markdown]
# Using the labels you identified above, you want to now run it through the entire data

# %%
classifier  = pipeline("zero-shot-classification",  model = "facebook/bart-large-mnli")

# %%
# insert the labels you identified from above section
type = ['cost', 'efficient', 'effective', 'ease of use','affordability', 'quality', 'satisfaction']

# %%
#setting empty values for the columns
index = -1
for label in type:
    df[label + '_m'] = -1

for j in range(len(df)):
    #counter for progress/debugging
    index+=1
    if(index%20 == 0): 
        print(index)
        
    #running the classifier on the column    
    res = classifier(
        df.iloc[j]['review_lower'],
        candidate_labels = type,
        multi_label = True
    )
    #setting the column values according to the output from the classifier ("_m" = multiclass)
    for i in range(len(res['labels'])):
        df[res['labels'][i]+ '_m'].iloc[j] = res['scores'][i]
# Out:
# 0
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380

# %%
# create a "max" column for metric purposes
df['max'] = df[['cost_m', 'efficient_m', 'effective_m', 'ease of use_m','affordability_m', 'quality_m', 'satisfaction_m']].max(axis=1)

# %%
#assign the max to its aligned type
align_list=[]
for i in range(len(df)):
  for t in type:
    if df[t+'_m'].iloc[i] == df['max'].iloc[i]:
      align_list.append(t)
      
df['align_type']=align_list

# %%
df.head(3)
# Out:
#       segment  review_id                                      product_name  \
# 3025   Garden      28006                Lawn Booster Sun & Shade 9.6lb bag
# 16018  Garden     100613            Smart Seed Sun & Shade Mixture 7lb bag
# 5696   Garden      65399  Pennington Smart Patch Sun & Shade Mix, 5 lb Jug
#
#                                               producturl   retailer  \
# 3025              http://www.homedepot.com/p/t/311569530  Homedepot
# 16018               http://www.homedepot.com/p/314933321  Homedepot
# 5696   https://www.lowes.com/pd/Pennington-Smart-Patc...      Lowes
#
#                  brand retailer_product_id     base_id variants_flag  \
# 3025   PenningtonGrass           311569530   311569530           Yes
# 16018  PenningtonGrass           314933320   314933321           Yes
# 5696   PenningtonGrass          5005480037  5005480037           Yes
#
#       review_creation_date  year  month  week  \
# 3025   2021-10-18T00:00:00  2021     10    42
# 16018  2022-04-19T00:00:00  2022      4    16
# 5696   2021-11-01T00:00:00  2021     11    44
#
#                                             review_title  \
# 3025   After 9 days, no growth. I have used much fast...
# 16018  I followed the instructions and no grass has g...
# 5696                                         Smart Patch
#
#                                              review_text         review_type  \
# 3025   After 9 days, no growth. I have used much fast...     organic reviews
# 16018  I followed the instructions and no grass has g...     organic reviews
# 5696   [This review was collected as part of a promot...  syndicated reviews
#
#        price  rating  images  videos  helpful_votes promotion_flag  \
# 3025   17.98       2       0       0              0             No
# 16018  29.97       1       0       0              0             No
# 5696   16.98       5       0       0              0            Yes
#
#                                             review_lower        date  \
# 3025   after 9 days, no growth. i have used much fast...  2021-10-18
# 16018  i followed the instructions and no grass has g...  2022-04-19
# 5696   [this review was collected as part of a promot...  2021-11-01
#
#        word_count sentiment    cost_m  efficient_m  effective_m  \
# 3025           11  Negative  0.589395     0.541165     0.722956
# 16018          15  Negative  0.872405     0.002171     0.005709
# 5696           49  Positive  0.397894     0.993461     0.999078
#
#        ease of use_m  affordability_m  quality_m  satisfaction_m       max  \
# 3025        0.156047         0.287832   0.382058        0.024825  0.722956
# 16018       0.126067         0.119751   0.021837        0.001482  0.872405
# 5696        0.991363         0.425603   0.992153        0.982234  0.999078
#
#       align_type
# 3025   effective
# 16018       cost
# 5696   effective

# %%
import seaborn as sns

# %%
# Create Pivot table for the Heatmap

table = pd.pivot_table(df, values='max', index=['sentiment'], columns=['align_type'], aggfunc=np.mean,fill_value=0)
table
# Out:
# align_type  affordability      cost  ease of use  effective  efficient  \
# sentiment
# Negative         0.000000  0.736346     0.938779   0.836455   0.000000
# Neutral          0.000000  0.587405     0.906595   0.850829   0.640102
# Positive         0.983513  0.804223     0.993016   0.988539   0.925664
#
# align_type   quality  satisfaction
# sentiment
# Negative    0.235223      0.000000
# Neutral     0.803303      0.000000
# Positive    0.976265      0.991295

# %%
# Heatmap

plt.figure(figsize=(12, 5))
sns.set(font_scale=1.4)
# Reds
data1 = table.copy()
data1.loc['Negative'] = float('nan')
data1.loc['Neutral'] = float('nan')
ax=sns.heatmap(data1, annot=True, cmap="Greens", alpha=0.75,fmt=".3",annot_kws={"fontsize":15},linewidth=0.1,cbar=False)
ax.set(xlabel="", ylabel="")

# Blue
data2 = table.copy()
data2.loc['Negative'] = float('nan')
data2.loc['Positive'] = float('nan')
ax=sns.heatmap(data2, annot=True, cmap="Blues", alpha=0.75,fmt=".3",annot_kws={"fontsize":15},linewidth=0.1,cbar=False)
ax.set(xlabel="", ylabel="")
# Greens
data3 = table.copy()
data3.loc['Positive'] = float('nan')
data3.loc['Neutral'] = float('nan')
ax=sns.heatmap(data3, annot=True, cmap="Reds", alpha=0.75,fmt=".3",annot_kws={"fontsize":15},linewidth=0.1,cbar=False)
ax.set(xlabel="", ylabel="")
# Out:
# [Text(79.5, 0.5, ''), Text(0.5, 16.5, '')]
# [Text(79.5, 0.5, ''), Text(0.5, 16.5, '')]
# [Text(79.5, 0.5, ''), Text(0.5, 16.5, '')]

# %% [markdown]
# # Metric and Sanity Check

# %%
sns.set_style('ticks');
fig, ax = plt.subplots();
ax = sns.histplot(x = 'max', data = df);
plt.axvline(0.7, 0,700, c = 'r', ls = '--');

len(df[df['max'] > 0.7])/len(df['max'])
#subcategories of quality. may be too broad


list(df[df['max'] > 0.7]['review_lower'][1:2])
# Out:
# 0.8
# ['i followed the instructions and no grass has grown at all. disappointed. waste of money.']

# %%
# to see how many uncategorized data remains
df_uncat = df[df['cost_m'] < 0.7]
df_uncat = df_uncat[df_uncat['efficient_m'] < 0.7]
df_uncat = df_uncat[df_uncat['effective_m'] < 0.7]
df_uncat = df_uncat[df_uncat['ease of use_m'] < 0.7]
df_uncat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 82 entries, 15086 to 3020
# Data columns (total 35 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   segment               82 non-null     object
#  1   review_id             82 non-null     int64
#  2   product_name          82 non-null     object
#  3   producturl            82 non-null     object
#  4   retailer              82 non-null     object
#  5   brand                 82 non-null     object
#  6   retailer_product_id   82 non-null     object
#  7   base_id               82 non-null     object
#  8   variants_flag         82 non-null     object
#  9   review_creation_date  82 non-null     object
#  10  year                  82 non-null     int64
#  11  month                 82 non-null     int64
#  12  week                  82 non-null     int64
#  13  review_title          81 non-null     object
#  14  review_text           82 non-null     object
#  15  review_type           82 non-null     object
#  16  price                 82 non-null     float64
#  17  rating                82 non-null     int64
#  18  images                82 non-null     int64
#  19  videos                82 non-null     int64
#  20  helpful_votes         82 non-null     int64
#  21  promotion_flag        82 non-null     object
#  22  review_lower          82 non-null     object
#  23  date                  82 non-null     object
#  24  word_count            82 non-null     int64
#  25  sentiment             82 non-null     object
#  26  cost_m                82 non-null     float64
#  27  efficient_m           82 non-null     float64
#  28  effective_m           82 non-null     float64
#  29  ease of use_m         82 non-null     float64
#  30  affordability_m       82 non-null     float64
#  31  quality_m             82 non-null     float64
#  32  satisfaction_m        82 non-null     float64
#  33  max                   82 non-null     float64
#  34  align_type            82 non-null     object
# dtypes: float64(9), int64(9), object(17)
# memory usage: 23.1+ KB

# %%
len(df_uncat)
# Out:
# 82
