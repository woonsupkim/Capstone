# %%
import sys
sys.path.insert(1, 'C:/Users/Woon/Desktop/Columbia/Applied Analytics/Term3/Capstone/lib')

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings("ignore")

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

pd.set_option('display.max_columns', None)

# %%
df_demo = pd.read_csv('data\demo_data.csv')
df_demo = df_demo.drop(columns=['Unnamed: 0'])
df_demo = df_demo.drop(columns=['Unnamed: 0.1'])
df_demo
# Out:
#     segment  review_id                                       product_name  \
# 0    Garden      67956  Eliminator Ready-to-Use Weed & Grass Killer He...
# 1    Garden      12228    IMAGE Herbicide Brush & Vine Killer Concentrate
# 2    Garden     141858  IMAGE Lawn Weed & Crabgrass Killer Ready-To-Spray
# 3    Garden      78430                 Lawn Booster Sun & Shade 9.6lb bag
# 4    Garden      70299                           Annual Ryegrass 50lb bag
# ..      ...        ...                                                ...
# 427  Garden     132485                 Lawn Booster Sun & Shade 9.6lb bag
# 428  Garden      70268  Alaska 5-1-1 Fish Fertilizer 5 Gal Bucket (con...
# 429  Garden     134305                          Sevin Ready-to-Use 1 gal.
# 430  Garden     136156             Smart Seed Dense Shade Mixture 7lb bag
# 431  Garden       5453             One Step Complete Sun & Shade 10lb bag
#
#                                             producturl   retailer  \
# ...

# %% [markdown]
# # Retailers

# %%
hue_order=['Positive', 'Negative', 'Neutral']
order=['Homedepot', 'Walmart', 'Lowes', 'Amazon']

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Retailers - cost');
sns.countplot(y='retailer', data=df_demo[df_demo['cost_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order=order);
plt.savefig('figs/retailers_cost.jpg', bbox_inches = 'tight');

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Retailers - Efficiency');
sns.countplot(y='retailer', data=df_demo[df_demo['efficient_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order=order);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Retailers - Effectiveness');
sns.countplot(y='retailer', data=df_demo[df_demo['effective_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order=order);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Retailers - Ease of Use');
sns.countplot(y='retailer', data=df_demo[df_demo['ease of use_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order=order);

# %% [markdown]
# # Brands

# %%
order = ['Eliminator', 'Image for Weeds', 'Pennington Grass', \
       'Pennington Bird', 'Pennington Fertilizer', 'GardenTech', \
       "Corry's", 'Amdro', 'Moss Out', 'Expert Gardener']

hue_order = ['Positive', 'Negative', 'Neutral']

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Brands - cost');
sns.countplot(y='brand', data=df_demo[df_demo['cost_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order = order);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Brands - Efficiency');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['efficient_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order = order);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Brands - Effectiveness');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['effective_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order = order);
plt.savefig('figs/brand_effective.jpg', bbox_inches = 'tight');

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Brands - Ease of Use');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['ease of use_m'] >= 0.7], hue = 'sentiment', hue_order=hue_order, order = order);

# %% [markdown]
# ## Homedepot

# %%
df_homedepot_cost=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Homedepot']
tab1 = pd.crosstab(index=df_homedepot_cost['sentiment'], columns='count')
100*tab1/tab1.sum()
print('\n')
df_homedepot_efficient=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Homedepot']
tab2 = pd.crosstab(index=df_homedepot_efficient['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_homedepot_effective=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Homedepot']
tab2 = pd.crosstab(index=df_homedepot_effective['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_homedepot_ease_of_use=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Homedepot']
tab2 = pd.crosstab(index=df_homedepot_ease_of_use['sentiment'], columns='count')
100*tab2/tab2.sum()
# Out:
# col_0        count
# sentiment
# Negative   48.4375
# Neutral    17.1875
# Positive   34.3750
# col_0       count
# sentiment
# Negative    6.875
# Neutral     8.750
# Positive   84.375
# col_0          count
# sentiment
# Negative   10.714286
# Neutral    13.265306
# Positive   76.020408
# col_0          count
# sentiment
# Negative    2.197802
# Neutral     9.890110
# Positive   87.912088

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Homedepot Brands - cost');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Homedepot'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Homedepot Brands - efficient');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Homedepot'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Homedepot Brands - effective');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Homedepot'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Homedepot Brands - ease of use');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Homedepot'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %% [markdown]
# ## Walmart

# %%
df_walmart_cost=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Walmart']
tab1 = pd.crosstab(index=df_walmart_cost['sentiment'], columns='count')
100*tab1/tab1.sum()
print('\n')
df_walmart_efficient=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Walmart']
tab2 = pd.crosstab(index=df_walmart_efficient['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_walmart_effective=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Walmart']
tab2 = pd.crosstab(index=df_walmart_effective['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_walmart_ease_of_use=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Walmart']
tab2 = pd.crosstab(index=df_walmart_ease_of_use['sentiment'], columns='count')
100*tab2/tab2.sum()
# Out:
# col_0          count
# sentiment
# Negative   22.580645
# Positive   77.419355
# col_0          count
# sentiment
# Negative    1.724138
# Neutral     5.172414
# Positive   93.103448
# col_0          count
# sentiment
# Negative    3.030303
# Neutral     6.060606
# Positive   90.909091
# col_0       count
# sentiment
# Neutral     3.125
# Positive   96.875

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Walmart Brands - cost');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Walmart'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Walmart Brands - efficient');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Walmart'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Walmart Brands - effective');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Walmart'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Walmart Brands - ease of use');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Walmart'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %% [markdown]
# ## Lowes

# %%
df_lowes_cost=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Lowes']
tab1 = pd.crosstab(index=df_lowes_cost['sentiment'], columns='count')
100*tab1/tab1.sum()
print('\n')
df_lowes_efficient=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Lowes']
tab2 = pd.crosstab(index=df_lowes_efficient['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_lowes_effective=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Lowes']
tab2 = pd.crosstab(index=df_lowes_effective['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_lowes_ease_of_use=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Lowes']
tab2 = pd.crosstab(index=df_lowes_ease_of_use['sentiment'], columns='count')
100*tab2/tab2.sum()
# Out:
# col_0          count
# sentiment
# Negative   52.941176
# Neutral     5.882353
# Positive   41.176471
# col_0          count
# sentiment
# Negative   10.416667
# Neutral     8.333333
# Positive   81.250000
# col_0          count
# sentiment
# Negative   16.666667
# Neutral     9.259259
# Positive   74.074074
# col_0          count
# sentiment
# Negative    6.060606
# Neutral     6.060606
# Positive   87.878788

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Lowes Brands - cost');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Lowes'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Lowes Brands - efficient');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Lowes'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Lowes Brands - effective');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Lowes'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Lowes Brands - ease of use');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Lowes'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %% [markdown]
# ## Amazon

# %%
df_Amazon_cost=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Amazon']
tab1 = pd.crosstab(index=df_Amazon_cost['sentiment'], columns='count')
100*tab1/tab1.sum()
print('\n')
df_Amazon_efficient=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Amazon']
tab2 = pd.crosstab(index=df_Amazon_efficient['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_Amazon_effective=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Amazon']
tab2 = pd.crosstab(index=df_Amazon_effective['sentiment'], columns='count')
100*tab2/tab2.sum()
print('\n')
df_Amazon_ease_of_use=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Amazon']
tab2 = pd.crosstab(index=df_Amazon_ease_of_use['sentiment'], columns='count')
100*tab2/tab2.sum()
# Out:
# col_0          count
# sentiment
# Negative   80.000000
# Neutral     6.666667
# Positive   13.333333
# col_0          count
# sentiment
# Negative   27.777778
# Neutral    22.222222
# Positive   50.000000
# col_0          count
# sentiment
# Negative   31.818182
# Neutral    22.727273
# Positive   45.454545
# col_0      count
# sentiment
# Neutral     37.5
# Positive    62.5

# %%
#cost_m	efficient_m	effective_m	ease of use_m
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Amazon Brands - cost');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['cost_m'] >= 0.7][df_demo[df_demo['cost_m'] >= 0.7]['retailer'] == 'Amazon'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
#cost_m	efficient_m	effective_m	ease of use_m
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Amazon Brands - efficient');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['efficient_m'] >= 0.7][df_demo[df_demo['efficient_m'] >= 0.7]['retailer'] == 'Amazon'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Amazon Brands - effective');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['effective_m'] >= 0.7][df_demo[df_demo['effective_m'] >= 0.7]['retailer'] == 'Amazon'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %%
#cost_m	efficient_m	effective_m	ease of use_m
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Amazon Brands - ease of use');
hue_order = ['Positive', 'Negative', 'Neutral']
sns.countplot(y='brand', data=df_demo[df_demo['ease of use_m'] >= 0.7][df_demo[df_demo['ease of use_m'] >= 0.7]['retailer'] == 'Amazon'], hue = 'sentiment', hue_order=['Positive', 'Negative', 'Neutral']);

# %% [markdown]
# # Insights

# %%
df_demo2 = df_demo[df_demo['retailer'] == 'Homedepot']
df_demo2 = df_demo2[df_demo2['sentiment'] == 'Negative']
#df_demo2 = df_demo[df_demo['retailer'] == 'Homedepot'][df_demo[df_demo['retailer'] == 'Homedepot']['sentiment'] == 'Negative']

# %%
fig,ax = plt.subplots()
fig.set_size_inches(10,6)
plt.title('Top 10 Products from Homedepot with Negative sentiment');
sns.countplot(y = 'product_name', data = df_demo[df_demo['retailer'] == 'Homedepot'][df_demo[df_demo['retailer'] == 'Homedepot']['sentiment'] == 'Negative'], order = df_demo[df_demo['retailer'] == 'Homedepot'][df_demo[df_demo['retailer'] == 'Homedepot']['sentiment'] == 'Negative']['product_name'].value_counts()[0:10].index, palette = "muted")
plt.savefig('figs/negative_homedepot', bbox_inches = 'tight');
